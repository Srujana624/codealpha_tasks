# %% [markdown]
# <a href="https://colab.research.google.com/github/Srujana624/codealpha_tasks/blob/main/CodeAlphaTask4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# You can upload a file directly from your local system to the Colab environment using `google.colab.files.upload()`. After uploading, you can read the CSV file into a pandas DataFrame.

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')

# Assuming you upload a CSV file, you can then read it like this:
# You might need to change 'your_uploaded_file.csv' to the actual name of your uploaded file.
# df = pd.read_csv(list(uploaded.keys())[0]) # Reads the first uploaded file
# display(df.head())
# Out:
#      <input type="file" id="files-c7f35d85-9665-4f06-963c-233f01707264" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7f35d85-9665-4f06-963c-233f01707264">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Advertising.csv")
print(df.head())
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.dropna(inplace=True)

# %%
X = df[['TV', 'Radio', 'Newspaper']]  # advertising spend
y = df['Sales']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X)

# %%
plt.figure()
plt.scatter(df['TV'], df['Sales'])
plt.plot(df['TV'], predictions)
plt.title("Sales vs TV Advertising")
plt.show()
